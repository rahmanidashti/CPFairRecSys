# %%
import pandas as pd

# %%
datasets = ["MovieLens100K", "Gowalla", "Foursquare", "Epinion", "LastFM", "BookCrossing", "AmazonOffice", "AmazonToy"]
user_threasholds = [10, 20, 50, 100]
item_threasholds = [10, 20, 50, 100]

# %%
for dataset in datasets:
    train_data = pd.read_csv(f"datasets/{dataset}/{dataset}_train.txt", sep='\t', names=['uid', 'iid', 'rating'])
    num_users = len(train_data['uid'].unique())
    num_items = len(train_data['iid'].unique())
    print(num_users, num_items)
    for threashold in user_threasholds:
        uid_value_counts = train_data['uid'].value_counts()
        user_count = uid_value_counts[uid_value_counts >= threashold].count()
        print(f"No. of users in {dataset} with >= {threashold} ineractions: {user_count} - {round(user_count * 100 / num_users, 2)}")

    print()

    for threashold in item_threasholds:
        # item side fewer than ds_rate cheking
        iid_value_counts = train_data['iid'].value_counts()
        item_count = iid_value_counts[iid_value_counts >= threashold].count()
        # print(f"No. of items < {ds[ds_config]['ds_core']} ineractions: {item_interaction}")
        print(f"No. of items in {dataset} with >= {threashold} ineractions: {item_count} - {round(item_count * 100 / num_items, 2)}")
    
    print()
# Out:
# 943 1349
# No. of users in MovieLens100K with >= 10 ineractions: 943 - 100.0
# No. of users in MovieLens100K with >= 20 ineractions: 774 - 82.08
# No. of users in MovieLens100K with >= 50 ineractions: 443 - 46.98
# No. of users in MovieLens100K with >= 100 ineractions: 246 - 26.09
#
# No. of items in MovieLens100K with >= 10 ineractions: 1044 - 77.39
# No. of items in MovieLens100K with >= 20 ineractions: 816 - 60.49
# No. of items in MovieLens100K with >= 50 ineractions: 466 - 34.54
# No. of items in MovieLens100K with >= 100 ineractions: 222 - 16.46
#
# 1130 1189
# No. of users in Gowalla with >= 10 ineractions: 1130 - 100.0
# No. of users in Gowalla with >= 20 ineractions: 973 - 86.11
# No. of users in Gowalla with >= 50 ineractions: 287 - 25.4
# No. of users in Gowalla with >= 100 ineractions: 55 - 4.87
#
# No. of items in Gowalla with >= 10 ineractions: 1189 - 100.0
# No. of items in Gowalla with >= 20 ineractions: 1004 - 84.44
# No. of items in Gowalla with >= 50 ineractions: 239 - 20.1
# No. of items in Gowalla with >= 100 ineractions: 47 - 3.95
#
# 1568 1461
# No. of users in Foursquare with >= 10 ineractions: 1458 - 92.98
# No. of users in Foursquare with >= 20 ineractions: 555 - 35.4
# No. of users in Foursquare with >= 50 ineractions: 22 - 1.4
# No. of users in Foursquare with >= 100 ineractions: 1 - 0.06
#
# No. of items in Foursquare with >= 10 ineractions: 1310 - 89.66
# No. of items in Foursquare with >= 20 ineractions: 410 - 28.06
# No. of items in Foursquare with >= 50 ineractions: 68 - 4.65
# No. of items in Foursquare with >= 100 ineractions: 19 - 1.3
#
# 2677 2060
# No. of users in Epinion with >= 10 ineractions: 2673 - 99.85
# No. of users in Epinion with >= 20 ineractions: 1517 - 56.67
# No. of users in Epinion with >= 50 ineractions: 217 - 8.11
# No. of users in Epinion with >= 100 ineractions: 42 - 1.57
#
# No. of items in Epinion with >= 10 ineractions: 2056 - 99.81
# No. of items in Epinion with >= 20 ineractions: 1315 - 63.83
# No. of items in Epinion with >= 50 ineractions: 357 - 17.33
# No. of items in Epinion with >= 100 ineractions: 95 - 4.61
#
# 1797 1507
# No. of users in LastFM with >= 10 ineractions: 1731 - 96.33
# No. of users in LastFM with >= 20 ineractions: 1307 - 72.73
# No. of users in LastFM with >= 50 ineractions: 0 - 0.0
# No. of users in LastFM with >= 100 ineractions: 0 - 0.0
#
# No. of items in LastFM with >= 10 ineractions: 1115 - 73.99
# No. of items in LastFM with >= 20 ineractions: 563 - 37.36
# No. of items in LastFM with >= 50 ineractions: 226 - 15.0
# No. of items in LastFM with >= 100 ineractions: 73 - 4.84
#
# 1136 1019
# No. of users in BookCrossing with >= 10 ineractions: 676 - 59.51
# No. of users in BookCrossing with >= 20 ineractions: 149 - 13.12
# No. of users in BookCrossing with >= 50 ineractions: 3 - 0.26
# No. of users in BookCrossing with >= 100 ineractions: 0 - 0.0
#
# No. of items in BookCrossing with >= 10 ineractions: 628 - 61.63
# No. of items in BookCrossing with >= 20 ineractions: 178 - 17.47
# No. of items in BookCrossing with >= 50 ineractions: 13 - 1.28
# No. of items in BookCrossing with >= 100 ineractions: 1 - 0.1
#
# 2448 1595
# No. of users in AmazonOffice with >= 10 ineractions: 1062 - 43.38
# No. of users in AmazonOffice with >= 20 ineractions: 250 - 10.21
# No. of users in AmazonOffice with >= 50 ineractions: 5 - 0.2
# No. of users in AmazonOffice with >= 100 ineractions: 0 - 0.0
#
# No. of items in AmazonOffice with >= 10 ineractions: 717 - 44.95
# No. of items in AmazonOffice with >= 20 ineractions: 445 - 27.9
# No. of items in AmazonOffice with >= 50 ineractions: 88 - 5.52
# No. of items in AmazonOffice with >= 100 ineractions: 15 - 0.94
#
# 2170 1733
# No. of users in AmazonToy with >= 10 ineractions: 827 - 38.11
# No. of users in AmazonToy with >= 20 ineractions: 249 - 11.47
# No. of users in AmazonToy with >= 50 ineractions: 7 - 0.32
# No. of users in AmazonToy with >= 100 ineractions: 0 - 0.0
#
# No. of items in AmazonToy with >= 10 ineractions: 1002 - 57.82
# No. of items in AmazonToy with >= 20 ineractions: 324 - 18.7
# No. of items in AmazonToy with >= 50 ineractions: 7 - 0.4
# No. of items in AmazonToy with >= 100 ineractions: 0 - 0.0
